# %%
from corpus import MTCorpus

# %%
import numpy as np
np.set_printoptions(edgeitems=1000)

# %%
corpus = MTCorpus()

# %%
len(corpus.documents)
# Out:
# 112

# %%
corpus.documents[84:86]
# Out:
# [[Tomorrow I will skydive for the first time in my life.,
#   Yes, there is a certain risk to life.,
#   But I want to experience this incredible moment of freedom that skydivers report time and again.,
#   Besides, Jochen was given a parachute jump the other day as a gift,,
#   and it mustn't be that this wannabe-adventurer has one up on me.],
#  [Not everyone should be obliged to pay the TV & radio licence.,
#   Particularly the younger generations are no longer dependent on the programming of public broadcasters.,
#   US series are preferred over “Tatort”,,
#   and online magazines are turned to instead of the “Tagesthemen”.,
#   The TV & radio licence enables economically independent journalism.,
#   But as long as the licence payers have no say in the distribution of the funds, the fee quite rightly annoys them.]]

# %%
corpus.links[100]
# Out:
# [1, 1, 1, 1, 1]

# %%
corpus.types[84]
# Out:
# [1, 0, 0, 0, 0]

# %%
corpus.X_large[84][:][0]
# Out:
# array([ 1.00000000e+00,  1.47780269e-01,  2.36367583e-01, -7.93892518e-02,
#        -7.03279898e-02,  1.58585712e-01, -5.48295677e-02, -1.17294751e-02,
#        -4.30291593e-02,  1.29341587e-01,  2.23371243e+00, -3.25392455e-01,
#         1.17712915e-01,  1.65863827e-01,  3.01016811e-02, -3.02506667e-02,
#         8.53707492e-02, -5.89817762e-02,  1.07649410e+00, -1.89131394e-01,
#         3.09042465e-02, -1.46599188e-02, -1.05403729e-01, -2.82198866e-03,
#        -2.15889979e-02,  6.47447482e-02,  1.25054091e-01, -1.13620915e-01,
#        -1.05971575e-01, -3.67926694e-02,  7.93993548e-02, -1.00484423e-01,
#        -1.59471687e-02,  1.48503156e-02,  1.26212582e-01, -3.90966004e-03,
#         4.70675528e-02,  1.49155006e-01,  4.62270016e-03,  1.12432577e-02,
#        -8.75682570e-03,  4.94105034e-02,  1.45581350e-01, -5.72893322e-02,
#        -6.41866699e-02, -4.22081649e-02,  2.04691932e-01, -1.35101482e-01,
# ...

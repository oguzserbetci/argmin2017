# %%
import pickle
import numpy as np
import pandas as pd

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import sys
sys.path.append('../keras')
import train

# %% [markdown]
# ### Class distribution

# %%
docs_e, docs_d, links, types = train.load_vec('../corpus/X_large.npy','../corpus/X_large.npy','../corpus/Y_links_1.npy','../corpus/Y_types_1.npy')

# %%
Xe, Xd, Yl, Yt, _, _, _, _ = train.preprocess(docs_e, docs_d, links, types)

# %% [markdown]
# # Distributions

# %%
# a = plt.hist(np.array([t for typ in types for t in typ]), bins=np.arange(3)-.5)

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.title('Types class distribution')
plt.hist([t for typ in types for t in typ], bins=np.arange(3)-.5)
plt.xticks([0,1], ['Premise', 'Claim'])
plt.xlabel('Type')
plt.ylabel('N')

plt.subplot(122)
plt.title('Links class distribution')
plt.hist([l for link in links for l in link], bins=np.arange(10)-.5)
plt.xticks(np.arange(9))
plt.xlabel('Links')
plt.ylabel('N')
# Out:
# Text(0,0.5,'N')

# %%
np.histogram([t for typ in types for t in typ], bins=2)
Counter([t for typ in types for t in typ])
# Out:
# Counter({0: 1028, 1: 243})

# %% [markdown]
# ##### Extended

# %%
docs_e_ext, docs_d_ext, links_ext, types_ext = train.load_vec('../corpus/encoder_input_ext.npy','../corpus/decoder_input_ext.npy','../corpus/Y_links_ext.npy','../corpus/Y_types_ext.npy')

# %%
max([l for link in links_ext for l in link])
# Out:
# 8

# %%
# a = plt.hist(np.array([t for typ in types for t in typ]), bins=np.arange(3)-.5)

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.title('Types class distribution')
plt.hist([t for typ in types_ext for t in typ], bins=np.arange(3)-.5)
plt.xticks([0,1], ['Premise', 'Claim'])
plt.xlabel('Type')
plt.ylabel('N')

plt.subplot(122)
plt.title('Links class distribution')
plt.hist([l for link in links_ext for l in link], bins=np.arange(10)-.5)
plt.xticks(np.arange(9))
plt.xlabel('Links')
plt.ylabel('N')
# Out:
# Text(0,0.5,'N')
